# %% [markdown]
# # Prediction Notebook
# This notebook scores currently open deals, computes SHAP explanations, and saves the final predictions.

# %%
import src.predict as pred

# Execute inference and predictions
pred.run_predictions()

# %% [markdown]
# ## Inspect Output Datasets
# Let's load the generated opportunity predictions.

# %%
preds_df = pd.read_csv('output/opportunity_predictions.csv')
print('Row count:', len(preds_df))
preds_df[['Opportunity Number', 'Client', 'Win Probability', 'Risk Score', 'Predicted Next Stage', 'Top Driver 1']].head(5)
