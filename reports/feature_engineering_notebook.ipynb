# %% [markdown]
# # Feature Engineering Notebook
# This notebook details the time-aware feature calculations for the Opportunity Intelligence Platform.

# %%
import pandas as pd
import numpy as np
import src.features as feat

# Run the feature pipeline
feat.build_features()
print('Features calculated!')

# %% [markdown]
# ## Inspect Feature Distributions
# Let's load the generated features and inspect some statistics.

# %%
df = pd.read_pickle('processed_data/features_df.pkl')
df[['Opp_Age_Days', 'Num_Stage_Changes', 'Days_In_Current_Stage', 'Num_Slippages']].describe()
